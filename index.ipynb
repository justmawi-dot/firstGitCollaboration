# %%
detective = {"amy":85, "sandberg":68, "rosa":72}
print(detective)
# Out:
# {'amy': 85, 'andy': 68, 'rosa': 72}

# %%
import numpy as np
np.array([140, 150, 160, 170, 180, 190]) * 0.5
# Out:
# array([70., 75., 80., 85., 90., 95.])
